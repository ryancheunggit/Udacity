# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
from itertools import compress
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  # get the most common words sepecified by vocabulary - 1, 1 for UNK which stands for unknown
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  # build a dictionary which is word : inx mapping of all the most common words
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  # data is a list store the index of word in the dictionary of the most common words
  # enssentially data is a encoded version of words, with common word encoded as the index in the dictionary
  # and non-common words are encoded with the index of UNK
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  # reverse dictionary is the mapping from index to word of those most common words
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window

  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)  # this will loop data multiple times
    
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.521759
# Nearest to it: nuh, leslie, drives, amorphous, toilet, duvall, fido, keefe,
# Nearest to one: dv, grail, justified, paddock, inheriting, stockhausen, haiti, jpeg,
# Nearest to most: democrat, expanses, mojave, bonding, thesaurus, msc, tartarus, khartoum,
# Nearest to have: conformal, redirects, spark, tokyo, paraguayan, antecedent, leonis, tough,
# Nearest to nine: breaks, xie, trieste, lithuanians, cunt, primigenius, rathdown, streak,
# Nearest to two: bancroft, normalcy, biograph, relates, abol, keeper, discerned, madrid,
# Nearest to s: mosques, objector, aspires, partito, clip, precambrian, mcduck, satan,
# Nearest to would: showings, planned, conservatorio, cumings, kg, dues, turmoil, orchestras,
# Nearest to no: mixtures, optimism, dries, director, torch, features, woe, plead,
# Nearest to used: dumped, preservative, hormones, airways, anteaters, microtubules, pantera, terrorists,
# Nearest to their: elisabeth, raja, elegance, retrospect, fly, bainbridge, magneto, minimum,
# Nearest to only: bactrian, modules, declined, gravitating, monotonicity, att, sleep, lexicology,
# Nearest to during: ergodic, obvious, plummer, virtuoso, tamper, snes, cooke, silo,
# Nearest to the: unforgiven, comanche, highwayman, occultist, srinagar, variability, crete, shortness,
# Nearest to new: salicylate, sorel, enjoined, antoine, struggling, textbooks, taboos, verona,
# Nearest to over: millikan, telophase, tracing, balances, gibraltarians, divergences, judaizers, call,
# Average loss at step 2000: 4.368237
# Average loss at step 4000: 3.864256
# Average loss at step 6000: 3.786477
# Average loss at step 8000: 3.688520
# Average loss at step 10000: 3.617714
# Nearest to it: he, this, there, they, which, not, she, futurians,
# Nearest to one: two, six, eight, three, seven, os, four, wong,
# Nearest to most: ni, bonding, rosalynn, lambda, wedding, villein, salim, expanses,
# Nearest to have: be, has, had, were, are, mideast, redirects, shapes,
# Nearest to nine: eight, six, seven, five, zero, three, four, two,
# Nearest to two: three, four, five, seven, six, eight, nine, zero,
# Nearest to s: and, his, or, steffi, curlers, was, komm, intermediaries,
# Nearest to would: lurking, oppose, turmoil, can, will, parentheses, may, dues,
# Nearest to no: logician, semitone, contradict, merciful, rondo, a, initial, archivist,
# Nearest to used: dumped, known, microtubules, chalice, hormones, idleness, attached, troilus,
# Nearest to their: his, its, elisabeth, raja, iir, boise, capitan, volvo,
# Nearest to only: cursive, diachronic, wagers, att, lonesome, ravens, our, woodpeckers,
# Nearest to during: physicians, squadrons, tamper, on, cooke, snes, ergodic, reflectivity,
# Nearest to the: its, an, this, a, his, strengthened, disrepair, kristian,
# Nearest to new: salicylate, antoine, organization, ice, adversarial, hermann, nazarian, provincias,
# Nearest to over: vater, telophase, millikan, gibraltarians, euthanasia, balances, ero, irony,
# Average loss at step 12000: 3.604138
# Average loss at step 14000: 3.571094
# Average loss at step 16000: 3.404574
# Average loss at step 18000: 3.455630
# Average loss at step 20000: 3.548180
# Nearest to it: he, this, there, she, not, they, which, morality,
# Nearest to one: two, four, three, five, seven, eight, six, nine,
# Nearest to most: some, many, more, lambda, rosalynn, ni, villein, wedding,
# Nearest to have: had, has, be, were, are, mideast, courtroom, monophyletic,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to two: three, five, four, six, one, eight, seven, zero,
# Nearest to s: improving, inquisitor, haaretz, aor, symphonie, evidently, tandy, precipitous,
# Nearest to would: will, can, could, may, should, oppose, turmoil, lurking,
# Nearest to no: semitone, a, bentley, contradict, merciful, rondo, initial, it,
# Nearest to used: known, owned, dumped, monopoly, microtubules, kenyan, interferon, published,
# Nearest to their: his, its, the, her, some, many, all, any,
# Nearest to only: cursive, jia, nationalisation, overheard, lonesome, always, unconfirmed, sidearm,
# Nearest to during: physicians, in, entire, at, fluke, tamper, snes, vampyre,
# Nearest to the: their, its, this, his, an, disrepair, premierships, a,
# Nearest to new: salicylate, antoine, ruining, adversarial, ice, pantheist, nazarian, mortgages,
# Nearest to over: millikan, vater, tabs, gibraltarians, anhydride, hustler, telophase, euthanasia,
# Average loss at step 22000: 3.508996
# Average loss at step 24000: 3.492079
# Average loss at step 26000: 3.476779
# Average loss at step 28000: 3.484298
# Average loss at step 30000: 3.505105
# Nearest to it: he, she, there, they, this, which, not, also,
# Nearest to one: two, seven, four, five, eight, six, three, nine,
# Nearest to most: some, many, more, villein, use, lambda, among, whistling,
# Nearest to have: had, has, were, are, be, having, mideast, include,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to s: his, incremented, intermediaries, and, sculptors, tandy, legislative, aerosmith,
# Nearest to would: can, will, could, may, should, must, cannot, to,
# Nearest to no: a, bentley, semitone, contradict, still, iis, it, any,
# Nearest to used: known, found, troilus, published, lent, present, legendre, monopoly,
# Nearest to their: its, his, the, her, many, some, any, these,
# Nearest to only: intonation, bureaucracies, real, not, butcher, always, vertically, june,
# Nearest to during: in, after, at, dougherty, physicians, entire, fluke, makeover,
# Nearest to the: their, its, his, a, blackpool, spectacles, nguema, her,
# Nearest to new: salicylate, ruining, adversarial, single, montoneros, filenames, allahabad, dhea,
# Nearest to over: overall, baur, among, hustler, sabers, pali, euthanasia, edited,
# Average loss at step 32000: 3.497978
# Average loss at step 34000: 3.497149
# Average loss at step 36000: 3.457151
# Average loss at step 38000: 3.305846
# Average loss at step 40000: 3.429887
# Nearest to it: he, there, she, they, this, often, not, never,
# Nearest to one: two, seven, four, six, eight, five, three, nine,
# Nearest to most: more, some, less, villein, many, rosalynn, among, lambda,
# Nearest to have: had, has, were, be, are, cements, having, courtroom,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to s: his, boniface, aor, cladistics, muscle, sondheim, baptize, evidently,
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to no: bentley, any, iis, issues, still, speedily, already, humphrey,
# Nearest to used: known, found, referred, considered, determined, seen, regarded, lent,
# Nearest to their: its, his, her, the, any, my, some, your,
# Nearest to only: intonation, bureaucracies, first, herodotus, real, repayment, it, vertically,
# Nearest to during: after, until, at, in, through, before, entire, under,
# Nearest to the: its, their, each, his, a, this, any, cordoba,
# Nearest to new: salicylate, equus, adversarial, voyaging, stereotyping, cheque, ruining, rede,
# Nearest to over: vater, under, guillaume, about, hesse, millikan, euthanasia, phobias,
# Average loss at step 42000: 3.435311
# Average loss at step 44000: 3.448910
# Average loss at step 46000: 3.451100
# Average loss at step 48000: 3.352451
# Average loss at step 50000: 3.385036
# Nearest to it: he, there, she, this, they, now, then, still,
# Nearest to one: two, six, eight, four, seven, five, three, nine,
# Nearest to most: more, less, among, many, some, expose, stained, lambda,
# Nearest to have: had, has, were, be, are, mideast, having, esaf,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to two: three, four, six, eight, five, seven, one, nine,
# Nearest to s: duly, whose, maquis, zorro, although, rpp, conservatism, and,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to no: any, bentley, a, humphrey, iis, semitone, issues, speedily,
# Nearest to used: known, referred, seen, regarded, determined, written, considered, found,
# Nearest to their: its, his, her, the, any, your, these, dissenters,
# Nearest to only: sidearm, first, repayment, always, fickle, yorker, all, vertically,
# Nearest to during: after, in, until, at, before, when, through, since,
# Nearest to the: its, their, his, some, this, any, a, cays,
# Nearest to new: single, salicylate, rede, stereotyping, lindsey, troll, caspase, second,
# Nearest to over: about, vater, millikan, guillaume, overall, phobias, serapeum, sloop,
# Average loss at step 52000: 3.433673
# Average loss at step 54000: 3.422394
# Average loss at step 56000: 3.437053
# Average loss at step 58000: 3.399873
# Average loss at step 60000: 3.389208
# Nearest to it: he, there, she, this, they, still, now, what,
# Nearest to one: two, four, eight, six, seven, five, three, nine,
# Nearest to most: some, many, more, use, stained, expose, less, lambda,
# Nearest to have: has, had, are, were, be, having, cfl, include,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to two: four, three, five, one, six, eight, seven, nine,
# Nearest to s: whose, drucker, yad, duly, gaddis, isbn, inquisitor, drier,
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to no: any, iis, intermediates, a, bentley, almighty, humphrey, little,
# Nearest to used: known, seen, called, written, published, found, regarded, available,
# Nearest to their: its, his, her, your, the, waterproof, my, organists,
# Nearest to only: sidearm, butcher, always, first, repayment, not, nationalisation, gsm,
# Nearest to during: after, until, before, in, although, at, when, since,
# Nearest to the: its, a, their, any, this, gilberts, some, his,
# Nearest to new: salicylate, single, ruining, equus, rede, stereotyping, caspase, adversarial,
# Nearest to over: about, guillaume, millikan, between, across, within, phobias, around,
# Average loss at step 62000: 3.243603
# Average loss at step 64000: 3.253286
# Average loss at step 66000: 3.400401
# Average loss at step 68000: 3.391945
# Average loss at step 70000: 3.362800
# Nearest to it: he, there, she, this, they, still, semitone, now,
# Nearest to one: seven, two, six, four, eight, five, three, nine,
# Nearest to most: more, less, many, some, expose, stained, use, whistling,
# Nearest to have: had, has, are, were, include, cfl, having, be,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to two: three, six, four, seven, five, one, eight, nine,
# Nearest to s: whose, duly, my, cladistics, gresham, motherhood, your, isbn,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to no: little, lud, humphrey, iis, bentley, any, intermediates, almighty,
# Nearest to used: known, seen, written, regarded, found, cited, available, referred,
# Nearest to their: its, his, her, my, your, the, cushitic, our,
# Nearest to only: always, fickle, not, sidearm, yorker, first, butcher, next,
# Nearest to during: after, until, before, in, throughout, at, since, following,
# Nearest to the: a, its, their, any, this, cordoba, another, each,
# Nearest to new: adversarial, domination, cheque, single, salicylate, troll, stereotyping, lindsey,
# Nearest to over: about, overall, guillaume, katha, phobias, millikan, further, across,
# Average loss at step 72000: 3.368015
# Average loss at step 74000: 3.347280
# Average loss at step 76000: 3.309199
# Average loss at step 78000: 3.350567
# Average loss at step 80000: 3.377376
# Nearest to it: he, she, there, this, they, we, never, still,
# Nearest to one: seven, six, two, three, eight, four, five, nine,
# Nearest to most: more, some, many, villein, less, whistling, among, codon,
# Nearest to have: had, has, are, were, be, include, having, cfl,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to s: idempotents, and, hlich, disambiguation, baptize, whose, asahi, inquisitor,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to no: little, davenport, humphrey, bentley, lud, depress, nothing, iis,
# Nearest to used: known, referred, seen, available, written, called, found, necessary,
# Nearest to their: its, his, her, my, your, our, the, whose,
# Nearest to only: yorker, last, fickle, first, next, sidearm, repayment, always,
# Nearest to during: after, until, in, before, when, throughout, while, following,
# Nearest to the: its, their, his, this, a, christiern, subscribe, katana,
# Nearest to new: parkinson, single, salicylate, voyages, stereotyping, raw, adversarial, particular,
# Nearest to over: around, within, across, about, phobias, guillaume, millikan, surf,
# Average loss at step 82000: 3.406763
# Average loss at step 84000: 3.409142
# Average loss at step 86000: 3.391258
# Average loss at step 88000: 3.352693
# Average loss at step 90000: 3.363844
# Nearest to it: he, she, this, there, they, therefore, actually, itself,
# Nearest to one: seven, two, four, eight, five, six, three, nine,
# Nearest to most: more, less, many, some, villein, particularly, use, stained,
# Nearest to have: had, has, were, are, be, having, include, cements,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to two: three, four, five, six, eight, one, seven, nine,
# Nearest to s: sincere, his, isbn, whose, confines, your, sculptors, olam,
# Nearest to would: could, will, can, might, may, should, must, cannot,
# Nearest to no: little, any, only, nothing, lud, humphrey, davenport, still,
# Nearest to used: known, referred, seen, called, regarded, given, determined, published,
# Nearest to their: its, his, her, your, my, our, whose, cushitic,
# Nearest to only: no, always, vanish, all, yorker, strategically, chukchi, sidearm,
# Nearest to during: after, until, before, while, in, since, throughout, at,
# Nearest to the: its, his, this, their, a, strived, gilberts, ewe,
# Nearest to new: salicylate, single, particular, stereotyping, unisys, parkinson, mortgages, encrypting,
# Nearest to over: within, about, around, off, phobias, guillaume, through, surf,
# Average loss at step 92000: 3.398822
# Average loss at step 94000: 3.251242
# Average loss at step 96000: 3.351393
# Average loss at step 98000: 3.241840
# Average loss at step 100000: 3.355954
# Nearest to it: he, she, there, this, they, still, allis, never,
# Nearest to one: two, seven, four, eight, five, nine, six, three,
# Nearest to most: more, less, use, stained, villein, particularly, many, whistling,
# Nearest to have: had, has, are, were, be, include, having, seem,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to s: whose, my, your, the, and, syntactic, isbn, his,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to no: little, any, humphrey, almighty, only, bentley, nothing, davenport,
# Nearest to used: known, referred, seen, written, given, considered, found, called,
# Nearest to their: its, his, her, your, our, the, my, whose,
# Nearest to only: no, always, not, title, wastewater, offenses, strategically, ruin,
# Nearest to during: after, until, in, before, throughout, when, through, since,
# Nearest to the: their, each, its, your, a, our, his, some,
# Nearest to new: single, separate, different, encrypting, adversarial, cheque, salicylate, rede,
# Nearest to over: within, around, across, about, phobias, guillaume, euthanasia, through,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
    
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # used for collecting data[data_index] in the sliding window

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  for i in range(batch_size):
    mask = [1] * span
    mask[skip_window] = 0 
    batch[i, :] = list(compress(buffer, mask)) # all surrounding words
    labels[i, 0] = buffer[skip_window] # the word at the center 
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]]) # An ordered sentence

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[i] for i in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # Computes the sum of embedding vectors for the given ids
  embed = tf.zeros([batch_size, embedding_size])
  for j in range(num_skips):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.789017
# Nearest to seven: maris, exercised, minuscule, iced, field, profitable, saxophones, glans,
# Nearest to b: johan, eps, honduran, loyalties, connoisseur, sicily, hertz, symbiosis,
# Nearest to they: disintegrating, hazara, beetle, summit, alomar, humps, orbitals, par,
# Nearest to may: mascarenhas, lizards, esperanto, deployed, mention, connections, nr, nuremberg,
# Nearest to that: devoting, rabat, lifeson, lest, zal, jolley, edge, UNK,
# Nearest to such: mack, heh, elevators, basset, kitab, masamune, princeps, digs,
# Nearest to can: braided, interventionism, economies, reintegrated, rulers, heroine, basie, numerically,
# Nearest to no: marine, iwerks, inward, dreyfus, thirsty, topol, pilgrimages, franca,
# Nearest to had: pemberton, unbounded, chimneys, stun, magnates, cinematic, seth, abbasids,
# Nearest to a: maxima, extinct, robert, cot, maharal, vats, suffix, stay,
# Nearest to have: enjoy, engraved, meine, grander, verlag, wrexham, megas, pemberton,
# Nearest to on: ferraris, madison, fruit, trainee, respiratory, insulted, appia, semimajor,
# Nearest to eight: chinaman, midlands, cannae, whitaker, personalities, gollancz, clients, technicalities,
# Nearest to people: renounce, harnessing, silk, sienkiewicz, carolinas, hoses, composting, shaughnessy,
# Nearest to three: saint, swat, citizenship, keitel, sines, interview, offer, translation,
# Nearest to all: mom, omni, broadcasts, playboys, cpus, sparta, paradigmatic, sandstorms,
# Average loss at step 2000: 4.099377
# Average loss at step 4000: 3.562521
# Average loss at step 6000: 3.390922
# Average loss at step 8000: 3.241321
# Average loss at step 10000: 3.180070
# Nearest to seven: eight, nine, four, five, six, three, two, zero,
# Nearest to b: d, hayward, insulator, woodpecker, honduran, lattimore, polygonal, invasive,
# Nearest to they: he, there, we, it, hazara, she, already, par,
# Nearest to may: can, would, might, should, cannot, will, could, precedents,
# Nearest to that: which, habsburg, this, bleed, devoting, perrault, it, dictate,
# Nearest to such: well, challenging, transformer, protester, known, forearm, empanadas, these,
# Nearest to can: may, will, would, could, should, cannot, heroine, might,
# Nearest to no: marine, dreyfus, hollerith, a, imitate, characterizations, scolded, any,
# Nearest to had: has, have, was, were, brumaire, gotovina, productive, would,
# Nearest to a: cot, fodder, no, connemara, ascertain, gilgal, grander, occurrences,
# Nearest to have: had, has, be, were, are, coalition, leary, engraved,
# Nearest to on: in, anfield, within, at, memnon, mae, ferraris, helena,
# Nearest to eight: nine, six, four, seven, five, three, two, zero,
# Nearest to people: bernardi, khosrau, druidism, men, apocryphal, lizard, lewd, names,
# Nearest to three: four, two, six, five, eight, seven, zero, nine,
# Nearest to all: several, causes, perpetually, some, these, many, playboys, bn,
# Average loss at step 12000: 3.206231
# Average loss at step 14000: 3.150886
# Average loss at step 16000: 3.177864
# Average loss at step 18000: 3.130513
# Average loss at step 20000: 2.989103
# Nearest to seven: six, eight, five, four, three, nine, zero, two,
# Nearest to b: d, youssef, sirens, pollinator, heartbreak, prop, disunity, agar,
# Nearest to they: we, he, there, you, she, these, it, insufficiently,
# Nearest to may: can, would, will, might, must, should, could, cannot,
# Nearest to that: which, this, what, augusto, wereman, ece, fingerprint, where,
# Nearest to such: well, challenging, these, many, known, some, protester, including,
# Nearest to can: may, will, would, could, cannot, should, might, must,
# Nearest to no: any, hollerith, a, birch, flaubert, characterizations, terribly, imitate,
# Nearest to had: has, have, was, having, marlowe, ever, productive, were,
# Nearest to a: the, another, knapp, connemara, no, every, karo, enough,
# Nearest to have: had, has, were, are, be, having, leary, theta,
# Nearest to on: upon, in, within, at, insulted, anfield, christiansen, longbowmen,
# Nearest to eight: six, seven, nine, four, zero, five, three, two,
# Nearest to people: men, names, groups, squaw, bolshevism, draconis, kenilworth, appreciative,
# Nearest to three: four, six, seven, five, two, eight, zero, nine,
# Nearest to all: several, many, perpetually, these, any, various, causes, some,
# Average loss at step 22000: 3.072042
# Average loss at step 24000: 3.043377
# Average loss at step 26000: 2.999227
# Average loss at step 28000: 3.025274
# Average loss at step 30000: 3.008960
# Nearest to seven: nine, six, four, eight, five, three, two, zero,
# Nearest to b: d, madelyne, youssef, europium, dependant, heartbreak, c, lattimore,
# Nearest to they: we, there, he, you, she, repeatedly, it, these,
# Nearest to may: would, can, will, should, could, might, must, cannot,
# Nearest to that: which, however, this, what, when, carnival, fingerprint, ditches,
# Nearest to such: well, these, known, challenging, many, including, certain, sandpaper,
# Nearest to can: will, may, would, could, must, should, cannot, might,
# Nearest to no: any, hollerith, dhole, birch, dreyfus, imitate, a, refuting,
# Nearest to had: has, have, was, having, were, gave, won, yeats,
# Nearest to a: the, another, every, zoologists, any, insecure, connemara, guatemalan,
# Nearest to have: had, has, are, were, require, having, provide, include,
# Nearest to on: upon, anfield, within, in, under, at, delegations, rolling,
# Nearest to eight: nine, seven, six, five, four, zero, two, three,
# Nearest to people: men, draconis, tasman, names, women, days, americans, person,
# Nearest to three: four, six, two, five, seven, eight, one, nine,
# Nearest to all: any, both, some, each, these, perpetually, various, many,
# Average loss at step 32000: 2.827599
# Average loss at step 34000: 2.959120
# Average loss at step 36000: 2.945725
# Average loss at step 38000: 2.941484
# Average loss at step 40000: 2.934861
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to b: d, dependant, h, youssef, madelyne, heartbreak, pictured, insulator,
# Nearest to they: we, he, you, there, she, repeatedly, these, who,
# Nearest to may: can, would, will, could, might, must, should, cannot,
# Nearest to that: which, what, fingerprint, augusto, however, flares, ditches, hernandez,
# Nearest to such: well, these, known, challenging, including, opposed, follows, certain,
# Nearest to can: will, may, could, would, must, should, might, cannot,
# Nearest to no: any, little, hollerith, tolson, physicalism, dhole, chien, dreyfus,
# Nearest to had: has, have, was, having, were, already, became, never,
# Nearest to a: another, the, zoologists, insecure, every, arrowhead, enough, nicolas,
# Nearest to have: had, has, are, having, require, were, be, provide,
# Nearest to on: upon, within, anfield, through, under, in, festivities, aalborg,
# Nearest to eight: six, seven, nine, five, four, three, zero, two,
# Nearest to people: men, women, names, tasman, draconis, americans, children, peoples,
# Nearest to three: four, six, five, seven, eight, two, zero, nine,
# Nearest to all: many, both, various, some, any, every, several, those,
# Average loss at step 42000: 2.952625
# Average loss at step 44000: 2.956926
# Average loss at step 46000: 2.909743
# Average loss at step 48000: 2.870479
# Average loss at step 50000: 2.853227
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to b: d, leo, h, insulator, dependant, bandleaders, youssef, c,
# Nearest to they: we, there, you, he, she, it, repeatedly, these,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to that: which, what, however, fingerprint, holmium, augusto, trachea, diaz,
# Nearest to such: well, known, these, certain, challenging, follows, many, opposed,
# Nearest to can: may, could, will, must, would, might, should, cannot,
# Nearest to no: any, little, hollerith, lumped, dhole, only, guys, automatism,
# Nearest to had: has, have, was, were, having, subliminal, ve, would,
# Nearest to a: the, any, zoologists, another, every, amounts, connemara, backwardness,
# Nearest to have: had, has, require, were, are, be, having, provide,
# Nearest to on: upon, anfield, through, at, within, against, delegations, in,
# Nearest to eight: seven, nine, six, four, five, zero, three, two,
# Nearest to people: men, women, children, players, tasman, person, americans, christians,
# Nearest to three: four, two, seven, five, six, eight, zero, nine,
# Nearest to all: many, both, every, several, various, any, some, most,
# Average loss at step 52000: 2.891613
# Average loss at step 54000: 2.862693
# Average loss at step 56000: 2.857930
# Average loss at step 58000: 2.750023
# Average loss at step 60000: 2.832215
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Nearest to b: d, c, dependant, leo, mohenjo, madelyne, youssef, cc,
# Nearest to they: we, you, he, there, she, it, repeatedly, who,
# Nearest to may: can, could, will, must, should, would, might, cannot,
# Nearest to that: which, what, however, fingerprint, trachea, conversion, hiring, augusto,
# Nearest to such: known, well, these, certain, follows, opposed, many, challenging,
# Nearest to can: could, will, may, should, must, would, might, cannot,
# Nearest to no: little, another, any, hollerith, dhole, reconciliation, infinitesimals, automatism,
# Nearest to had: has, have, was, having, were, never, already, ve,
# Nearest to a: another, the, zoologists, insecure, czechoslovak, connemara, magie, no,
# Nearest to have: had, has, having, require, are, were, be, provide,
# Nearest to on: upon, within, at, in, through, anfield, under, around,
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to people: men, children, women, players, christians, person, americans, jews,
# Nearest to three: four, six, two, five, seven, eight, zero, nine,
# Nearest to all: many, both, various, every, several, those, any, some,
# Average loss at step 62000: 2.833288
# Average loss at step 64000: 2.775597
# Average loss at step 66000: 2.765703
# Average loss at step 68000: 2.715910
# Average loss at step 70000: 2.782413
# Nearest to seven: six, five, eight, nine, three, four, zero, two,
# Nearest to b: d, dependant, leo, eco, kofi, truffaut, youssef, motherland,
# Nearest to they: we, you, he, she, there, it, these, who,
# Nearest to may: could, might, must, should, can, will, would, cannot,
# Nearest to that: which, augusto, what, but, however, hiring, fingerprint, crusades,
# Nearest to such: known, well, opposed, follows, these, defined, act, described,
# Nearest to can: will, could, must, should, may, might, cannot, would,
# Nearest to no: little, any, hollerith, resisted, another, hotham, automatism, thrash,
# Nearest to had: has, have, was, having, were, gradually, subsequently, dinaric,
# Nearest to a: another, the, any, zoologists, backwardness, connemara, abl, mitanni,
# Nearest to have: had, has, require, are, having, contain, were, be,
# Nearest to on: upon, in, within, at, under, anfield, around, putonghua,
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to people: men, women, children, players, person, jews, americans, peoples,
# Nearest to three: five, four, six, seven, two, eight, zero, nine,
# Nearest to all: both, many, various, every, perpignan, those, each, some,
# Average loss at step 72000: 2.802559
# Average loss at step 74000: 2.646226
# Average loss at step 76000: 2.799908
# Average loss at step 78000: 2.824760
# Average loss at step 80000: 2.786931
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Nearest to b: d, rex, dependant, swans, youssef, sp, leo, c,
# Nearest to they: we, you, he, there, she, it, these, i,
# Nearest to may: can, could, might, should, must, would, will, cannot,
# Nearest to that: which, what, this, however, often, insufficiently, about, augusto,
# Nearest to such: well, opposed, known, follows, these, certain, themselves, act,
# Nearest to can: could, will, may, must, should, might, would, cannot,
# Nearest to no: little, any, hollerith, rambam, automatism, fabulous, only, physicalism,
# Nearest to had: has, have, having, was, were, never, subsequently, gradually,
# Nearest to a: another, zoologists, connemara, any, abl, the, every, knapp,
# Nearest to have: had, has, are, were, require, having, provide, be,
# Nearest to on: upon, in, through, anfield, around, regarding, within, under,
# Nearest to eight: six, nine, seven, five, four, zero, three, two,
# Nearest to people: men, children, women, players, americans, person, speakers, peoples,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to all: both, various, many, any, every, several, some, each,
# Average loss at step 82000: 2.666500
# Average loss at step 84000: 2.770474
# Average loss at step 86000: 2.736769
# Average loss at step 88000: 2.753215
# Average loss at step 90000: 2.737059
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to b: d, c, f, dependant, log, sp, toughness, r,
# Nearest to they: we, you, he, she, there, it, i, who,
# Nearest to may: can, should, might, must, could, would, will, cannot,
# Nearest to that: which, what, however, fingerprint, where, this, hernandez, devoting,
# Nearest to such: well, known, follows, these, opposed, listed, act, possible,
# Nearest to can: could, should, may, will, must, might, would, cannot,
# Nearest to no: little, any, hollerith, another, nothing, rambam, become, only,
# Nearest to had: has, have, was, having, rasmussen, were, saw, sectional,
# Nearest to a: another, zoologists, the, abl, tigre, pundits, enough, any,
# Nearest to have: had, has, require, are, be, provide, having, were,
# Nearest to on: upon, in, through, anfield, concerning, within, regarding, enz,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to people: men, children, women, person, players, speakers, americans, peoples,
# Nearest to three: four, two, five, six, seven, eight, zero, nine,
# Nearest to all: both, various, many, any, every, some, each, several,
# Average loss at step 92000: 2.677144
# Average loss at step 94000: 2.724147
# Average loss at step 96000: 2.701600
# Average loss at step 98000: 2.363715
# Average loss at step 100000: 2.397804
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to b: d, dependant, coru, eco, kofi, methuen, truffaut, norfolk,
# Nearest to they: we, he, you, there, she, i, it, who,
# Nearest to may: should, must, could, might, would, can, will, cannot,
# Nearest to that: which, however, what, trachea, augusto, whom, how, devoting,
# Nearest to such: known, these, well, opposed, listed, destry, many, snapping,
# Nearest to can: could, must, should, will, might, cannot, would, may,
# Nearest to no: little, any, hollerith, nothing, another, latinate, resisted, dhole,
# Nearest to had: has, have, having, was, were, ve, vests, ever,
# Nearest to a: another, connemara, the, pundits, airfields, abl, knapp, stoke,
# Nearest to have: had, has, require, having, are, were, be, include,
# Nearest to on: upon, anticommunist, enz, anfield, at, festivities, almoravids, in,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to people: men, children, women, person, persons, players, jews, speakers,
# Nearest to three: five, four, seven, six, two, eight, nine, zero,
# Nearest to all: both, various, several, some, many, every, those, any,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
